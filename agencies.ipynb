# %% [markdown]
# <a href="https://colab.research.google.com/github/HailemariamHabtualem/school-management-/blob/master/agencies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.Series([1,2,3,4,5])
print(df)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
agencies = pd.read_excel("/test.xlsx")
print(agencies)
# Out:
#        Id Record Id File Identifier  IATA Areas  IATA Numeric Code  \
# 0       0         C              AC         3.0          8000720.0
# 1       0         C              AC         3.0          8000963.0
# 2       0         C              AC         3.0          8004500.0
# 3       0         C              AC         3.0          8004581.0
# 4       0         C              AC         3.0          8004905.0
# ...    ..       ...             ...         ...                ...
# 296114  0       NaN              AM         3.0         96146131.0
# 296115  0       NaN              AM         3.0         96173291.0
# 296116  0       NaN              AM         3.0         96613543.0
# 296117  0       NaN              AM         3.0         96142745.0
# 296118  0       NaN              AM         3.0         96173103.0
#
#         CASS Number Location Type Airline Code  \
# 0               NaN            HE          NaN
# 1               NaN            HE          NaN
# ...

# %%
agencies.head()
# Out:
#   Id Record Id File Identifier  IATA Areas  IATA Numeric Code  CASS Number  \
# 0  0         C              AC         3.0          8000720.0          NaN
# 1  0         C              AC         3.0          8000963.0          NaN
# 2  0         C              AC         3.0          8004500.0          NaN
# 3  0         C              AC         3.0          8004581.0          NaN
# 4  0         C              AC         3.0          8004905.0          NaN
#
#   Location Type Airline Code  \
# 0            HE          NaN
# 1            HE          NaN
# 2            HE          NaN
# 3            HE          NaN
# 4            HE          NaN
#
#                                           Legal Name Trading Name  ...  \
# 0     CHANGSHA CHINA FLY AVIATION     SERVICE CO.LTD          NaN  ...
# 1  SHANGHAI COSAVVY INTERNATIONAL  TRAVEL AGENCY ...          NaN  ...
# 2  HENAN CHANGXING TIANXIA AIR     TICKETING SERV...          NaN  ...
# ...

# %%
# prompt: generate a sample rows from the agencies and please consider the iata numeric code column as a text

import pandas as pd

# Assuming 'agencies' DataFrame is already loaded as shown in the prompt
# If not, load it here: agencies = pd.read_excel("/test.xlsx")

# Sample 5 rows
sample_agencies = agencies.sample(n=5)

# Convert 'IATA numeric code' column to string if it exists
if 'IATA numeric code' in sample_agencies.columns:
  sample_agencies['IATA numeric code'] = sample_agencies['IATA numeric code'].astype(str)

sample_agencies
# Out:
#        Id Record Id File Identifier  IATA Areas  IATA Numeric Code  \
# 139520  0         C              AC         1.0         86515892.0
# 171223  0         C              AC         1.0         57548540.0
# 50202   0       NaN              AM         2.0         92496541.0
# 215670  0       NaN              AM         1.0         49734694.0
# 199319  0       NaN              AM         1.0         57570376.0
#
#         CASS Number Location Type Airline Code  \
# 139520          NaN            HE          NaN
# 171223          NaN            AE          NaN
# 50202           NaN            HO           OS
# 215670          NaN            HO          NaN
# 199319          NaN            AE          NaN
#
#                                           Legal Name          Trading Name  \
# 139520                      MERELY TOURS S.A.DE C.V.          MERELY TOURS
# 171223         MILESSIS VIAGENS E TURISMO      LTDA.                   NaN
# ...

# %%
# prompt: generate a sample rows from the agencies and please consider the IATA Numeric Code column as a text

# Assuming 'agencies' DataFrame is already loaded as shown in the prompt
# If not, load it here: agencies = pd.read_excel("/test.xlsx")

# Sample 5 rows
sample_agencies = agencies.sample(n=5)

# Convert 'IATA numeric code' column to string if it exists
if 'IATA numeric code' in sample_agencies.columns:
    sample_agencies['IATA numeric code'] = sample_agencies['IATA numeric code'].astype(str)

sample_agencies
# Out:
#        Id Record Id File Identifier  IATA Areas  IATA Numeric Code  \
# 231049  0       NaN              AM         2.0         78225674.0
# 54014   0       NaN              AM         2.0         88492714.0
# 84656   0         C              AC         1.0         69960306.0
# 4611    0         A              AC         1.0         57969166.0
# 58681   0       NaN              AM         3.0          8094796.0
#
#         CASS Number Location Type Airline Code                    Legal Name  \
# 231049          NaN            AE          NaN  AVORIS RETAIL DIVISION; S.L.
# 54014           NaN            HO           LH                     LUFTHANSA
# 84656           NaN            AE          NaN                CWT CANADA LTD
# 4611            NaN            HO           TP              TAP AIR PORTUGAL
# 58681           NaN            HO           CX                CATHAY PACIFIC
#
#            Trading Name  ... Remittance Frequency 2 EasyPay Account Status  \
# ...

# %%
agencies.head(
)
# Out:
#   Id Record Id File Identifier  IATA Areas  IATA Numeric Code  CASS Number  \
# 0  0         C              AC         3.0          8000720.0          NaN
# 1  0         C              AC         3.0          8000963.0          NaN
# 2  0         C              AC         3.0          8004500.0          NaN
# 3  0         C              AC         3.0          8004581.0          NaN
# 4  0         C              AC         3.0          8004905.0          NaN
#
#   Location Type Airline Code  \
# 0            HE          NaN
# 1            HE          NaN
# 2            HE          NaN
# 3            HE          NaN
# 4            HE          NaN
#
#                                           Legal Name Trading Name  ...  \
# 0     CHANGSHA CHINA FLY AVIATION     SERVICE CO.LTD          NaN  ...
# 1  SHANGHAI COSAVVY INTERNATIONAL  TRAVEL AGENCY ...          NaN  ...
# 2  HENAN CHANGXING TIANXIA AIR     TICKETING SERV...          NaN  ...
# ...

# %%
# prompt: read all columns as a text file and display the head of the agencies

import pandas as pd

# Assuming the file exists in the current working directory or provide the correct path
try:
  agencies = pd.read_excel("/test.xlsx")
  print(agencies.head())
except FileNotFoundError:
  print("Error: File not found. Please provide the correct path to the Excel file.")
except Exception as e:
  print(f"An error occurred: {e}")
# Out:
#   Id Record Id File Identifier  IATA Areas  IATA Numeric Code  CASS Number  \
# 0  0         C              AC         3.0          8000720.0          NaN
# 1  0         C              AC         3.0          8000963.0          NaN
# 2  0         C              AC         3.0          8004500.0          NaN
# 3  0         C              AC         3.0          8004581.0          NaN
# 4  0         C              AC         3.0          8004905.0          NaN
#
#   Location Type Airline Code  \
# 0            HE          NaN
# 1            HE          NaN
# 2            HE          NaN
# 3            HE          NaN
# 4            HE          NaN
#
#                                           Legal Name Trading Name  ...  \
# 0     CHANGSHA CHINA FLY AVIATION     SERVICE CO.LTD          NaN  ...
# 1  SHANGHAI COSAVVY INTERNATIONAL  TRAVEL AGENCY ...          NaN  ...
# 2  HENAN CHANGXING TIANXIA AIR     TICKETING SERV...          NaN  ...
# ...
